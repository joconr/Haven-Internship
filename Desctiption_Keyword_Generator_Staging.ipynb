# %%
import importlib
import subprocess

# List of required packages
packages = ["os", "openai", "psycopg2", "bs4", "getpass", "datetime"]

# Loop through each package and check if it can be imported
for package in packages:
    try:
        importlib.import_module(package)
        print(f"{package} package is already installed")
    except ImportError:
        # If the package can't be imported, use pip to install it
        print(f"{package} package is not installed, installing now...")
        subprocess.check_call(["pip", "install", package])

import psycopg2
from bs4 import BeautifulSoup
import os
import openai
from getpass import getpass
from datetime import datetime
# Out:
# os package is already installed
# openai package is already installed
# psycopg2 package is already installed
# bs4 package is already installed
# getpass package is already installed
# datetime package is already installed

# %%
# Connect to the Postgres database
conn = psycopg2.connect(
    host="haven-staging-db-do-user-10050983-0.b.db.ondigitalocean.com",
    port=25060,
    dbname="staging",
    user="chatgpt_user", # Change user to your Postgres user
    password="--" # Change password to your Postgres password
)
cursor = conn.cursor()

# Set up OpenAI API credentials
openai.api_key = "YOUR_API_KEY_HERE" # Remember to insert your API key here

# Retrieve the description column data, SQL can be customized here
# I've set this to only return 10 specific opportunities for testing purposes, including one opportunity with no description
cursor.execute("SELECT id, description FROM opportunity o WHERE o.ID IN (73810, 77956, 24642, 46126, 62654, 9930, 46600, 55576, 20691, 58681);")
descriptions = cursor.fetchall()

# Loop through each description, extract the text using BeautifulSoup, and generate a summary using OpenAI API
for opportunity_id, description in descriptions:
    
    # If the description is empty, set a default summary and token
    if not description or description.strip() == "":
        print(f"Empty description for opportunity_id: {opportunity_id}")
        default_summary = "No description provided." # The default summary for no description can be customized here
        cursor.execute("""
            UPDATE opportunity SET gpt_description = %s, gpt_description_token = 0 WHERE id = %s
        """, (default_summary, opportunity_id))
        conn.commit()
        continue
    
    # If the description is not empty, generate a summary
    soup = BeautifulSoup(description, 'html.parser')
    text = soup.get_text()
    truncated_text = text[:15000] # The max number of characters for the API call can be customized here, but be careful as the token limit is 4096 (16384 characters for both input and output)

    # Generate a summary using OpenAI API
    response = openai.ChatCompletion.create(
        model='gpt-3.5-turbo',
        messages=[
            {"role": "system", "content": "You summarize opportunities from various government industries."}, # Adjusting system prompt can be customized here, but I've found it isn't as effective as the user prompt
            {"role": "user", "content": f'Summarize the contract work detail in the following text.: "{truncated_text}"'} # Adjusting user prompt can be customized here
        ],
        temperature=0,
    )

    # Print the summary and the number of tokens used
    summary = response['choices'][0]['message']['content'] 
    tokens = response['usage']['total_tokens']  # The number of tokens used is the cost of the API call
    print(summary)
    print(tokens)

    try:
            # Update the opportunity table with the summary and token count
            cursor.execute("""
                UPDATE opportunity SET gpt_description = %s, gpt_description_token = %s WHERE id = %s
            """, (summary, tokens, opportunity_id))
            conn.commit()
            print(f"Summary inserted for opportunity_id: {opportunity_id}")
    # If there is an error inserting into the table, print the error message
    except Exception as e:
        print(f"Error updating opportunity table for opportunity_id {opportunity_id}: {e}")
# Out:
# The contract work involves decommissioning one cabin building and one pit toilet structure in the Seward Ranger District of the Chugach National Forest. The contractor should refer to the attached amendment and SF-30 for more information. Additional satellite photos and responses to questions were added on August 31st.
# 152
# Summary inserted for opportunity_id: 9930
# The text describes a contract requirement for a Lektriever vertical carousel, which includes installation and shipping. The contractor is also required to review the telecom provisions and fill out the appropriate forms.
# 116
# Summary inserted for opportunity_id: 20691
# The New York State Thruway Authority is seeking bids for Contract TAN 22-28B/D214897 for Structural Steel Repairs, Seismic Retrofits, & Light Pole Replacements of the North Grand Island Bridges and Light Pole Replacements of the South Grand Island Bridges in Erie and Niagara Counties. Sealed bids must be hand-delivered or delivered by mail or overnight delivery service to the specified address by December 21, 2022, at 10:30 AM. The contract documents contain sensitive and/or confidential information that may only be used for the sole purpose of preparing a bid for this project. Prospective bidders must sign a confidentiality agreement with the Authority before they can review the contract documents. The bid must be secured with either a Bid Bond or a Bid Deposit. The Thruway Authority has discontinued the practice of reproducing and furnishing full-size and half-size plans to Contractors after contract award. Contractors shall be responsible for their own hard copies of plans and proposals at no additional cost to the Authority. The Thruway Authority continues to have public bid openings, however, there are measures in place to protect the safety and health of employees and visitors alike. The due date for the bid is December 21, 2022, at 10:30 AM.
# 1405
# Summary inserted for opportunity_id: 24642
# The government is looking to procure 34 units of a rotary pump, with a National Stock Number (NSN) of 4320016623913. The delivery location is W1A8 DLA DISTRIBUTION, and the delivery deadline is 0055 days after the order (ADO). The approved source for this procurement is 56529 101197-223. The solicitation is an RFQ (Request for Quote) and will only be available online. Hard copies of the solicitation, specifications, plans, or drawings are not available. All responsible sources can submit a quote, which must be submitted electronically and will be considered if received on time.
# 293
# Summary inserted for opportunity_id: 46126
# The government is looking to procure 22 units of a structural bracket (NSN 1560016915807) through an RFQ (Request for Quote) process. The contract may result in an Automated IDC (Indefinite Delivery Contract) with a term of one year or until the total orders reach $250,000. The estimated number of orders per year is 3, and the guaranteed minimum quantity is 3. The items will be shipped to various CONUS and OCONUS DLA Depots. The solicitation is only available electronically, and quotes must be submitted electronically by all responsible sources.
# 361
# Summary inserted for opportunity_id: 46600
# The Florida Department of Agriculture and Consumer Services is advertising a single source procurement opportunity, which is mandated by law. The department has attached documentation detailing the products and services to be procured and the justification for the single source procurement. Interested vendors who believe they can provide the commodities or contractual services must provide relevant information to the contact person listed on the advertisement by January 10, 2022. If the department determines that the commodities or contractual services are only available from a single source, it will post notice of its intended decision to enter into an agreement with the vendor on the Vendor Bid System.
# 330
# Summary inserted for opportunity_id: 55576
# Empty description for opportunity_id: 58681
# The Department of Veterans Affairs is seeking bids for a contract to upgrade the EHRM infrastructure at the Ft. Stockton, TX CBOC. The project is estimated to cost between $25,000 and $100,000 and is set aside for Veteran-Owned Small Businesses. The NAICS code for this procurement is 238210, and the small business size standard is $16.5 million. Interested contractors must contact Tammy Wilson, the POC for this project, and must be verified by the Department of Veterans Affairs Center for Verification and Evaluation (CVE) prior to submitting an offer. Failure to be verified by CVE and visible on VetBiz will result in the offer being deemed non-responsive.
# 497
# Summary inserted for opportunity_id: 62654
# The contract work involves the installation of concrete flat work, including sidewalk replacements, driveway apron replacements, installation of ADA ramps, curbing, etc. The work will be carried out at various locations within the Town of Cheektowaga in Erie County. The contract term is for the 2023 calendar year, and the due date for submission is March 22, 2023, at 11:00 AM. The contract is not a Service-Disabled Veteran-Owned Set Aside, and there are no MWBE participation goals. Valeri Concrete Construction, Inc. has been awarded a similar procurement contract in the past five years. The primary contact for the contract is Mark Christel, the Principal Engineering Assistant of the Town of Cheektowaga. The submission should be made to Jennifer Armstrong, the Town Clerk of Cheektowaga.
# 453
# Summary inserted for opportunity_id: 73810
# The City of Suffolk in Virginia has issued a Request for Proposals (RFP) for professional services related to geotechnical services. The closing date for the proposal submission is March 23, 2023, at 3:00 PM. The buyer for this opportunity is Jay Smigielski, who can be contacted via email or phone. The work location is in Suffolk, VA, and the opportunity is categorized under professional services. No website is provided for this opportunity.
# 240
# Summary inserted for opportunity_id: 77956

# %%
# Below is a separate script for generating keywords from the summary text
# However, I don't have user access to insert into the 'keyword' and 'opportunity_keyword' tables, so I've yet to test if it inserts correctly
# Feel free to test it on your own user account, I have a feeling everything should be working correctly or at least 99% there

# Retrieve the data from the 'gpt_description' table
cursor.execute("SELECT id, gpt_description FROM opportunity o WHERE o.ID IN (73810, 77956, 24642, 46126, 62654, 9930, 46600, 55576, 20691, 58681)") # Remember to change the SQL to match the opportunities you want to generate keywords for
descriptions = cursor.fetchall()

# Loop through each description and generate keywords using OpenAI gpt-3.5-turbo model
for desc in descriptions:
    cleanDesc = desc[1]

    # Check if the description is set to "No description provided."
    if cleanDesc == "No description provided.":
        print(f"No keywords generated for opportunity_id: {desc[0]} (no description provided)")
        continue

    response = openai.ChatCompletion.create(
    model='gpt-3.5-turbo',
    messages=[
        {"role": "system", "content": "You are an assistant generating keywords for government contracting descriptions."},
        {"role": "user", "content": f'Generate keywords for the following prompt. Keywords should relate ONLY to the work detail of the project involved. Ignore any names, dates, and emails. Separate keywords by commas: "{cleanDesc}"'}
    ],
    temperature=0,
    )
    keywords = response['choices'][0]['message']['content']
    tokens = response['usage']['total_tokens']
    keywords_list = [keyword.strip() for keyword in keywords.split(',')]  # Delimit and split the keywords by commas
    print(keywords_list)
    print(tokens)

    # Update the opportunity table with the gpt_keyword_token attribute
    cursor.execute("""
        UPDATE opportunity SET gpt_keyword_token = %s WHERE id = %s
    """, (tokens, desc[0]))
    
    # Insert the generated keyword data into the 'keyword' and 'opportunity_keyword' tables
    for keyword in keywords_list:
        # Check if the keyword already exists in the 'keyword' table
        cursor.execute("SELECT id FROM keyword WHERE type = 'opportunity' AND name = %s", (keyword,))
        keyword_id = cursor.fetchone()

        # If the keyword doesn't exist, insert it into the 'keyword' table and get its ID
        if keyword_id is None:
            cursor.execute(
                "INSERT INTO keyword (type, name) VALUES ('opportunity', %s) RETURNING id",
                (keyword,)
            )
            keyword_id = cursor.fetchone()[0]

        # Check if there's an existing entry in the 'opportunity_keyword' table
        cursor.execute(
            "SELECT * FROM opportunity_keyword WHERE opportunity_id = %s AND keyword_id = %s",
            (desc[0], keyword_id)
        )
        existing_entry = cursor.fetchone()

        # If there's no existing entry, insert the association into the 'opportunity_keyword' table
        if existing_entry is None:
            cursor.execute(
                "INSERT INTO opportunity_keyword (opportunity_id, keyword_id) VALUES (%s, %s)",
                (desc[0], keyword_id)
            )

    # commit changes to the database
    conn.commit()

conn.close()
# Out:
# ['contract work', 'decommissioning', 'cabin building', 'pit toilet structure', 'Seward Ranger District', 'Chugach National Forest', 'amendment', 'SF-30', 'satellite photos', 'responses', 'questions.']
# 157
# ---------------------------------------------------------------------------
# InsufficientPrivilege                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_44652/255545161.py in <module>
#      43         # If the keyword doesn't exist, insert it into the 'keyword' table and get its ID
#      44         if keyword_id is None:
# ---> 45             cursor.execute(
#      46                 "INSERT INTO keyword (type, name) VALUES ('opportunity', %s) RETURNING id",
#      47                 (keyword,)
#
# InsufficientPrivilege: permission denied for sequence keyword_id_seq
